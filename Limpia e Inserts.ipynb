# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import time
import pandas as pd
from selenium.webdriver.support.ui import Select
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
import numpy as np

# %%
hp1 = pd.read_csv('Harry Potter 1.csv',sep=';')
hp2 = pd.read_csv("Harry Potter 2.csv",sep=';')
hp3 = pd.read_csv("Harry Potter 3.csv",sep=';')
Character = pd.read_csv("Characters.csv",sep=';')
Potions = pd.read_csv("Potions.csv",sep=';')
Spells = pd.read_csv("Spells.csv",sep=';')

# %%
Character = pd.read_csv("Characters.csv",sep=';')

# %%
hp3.head()
# Out:
#       CHARACTER          SENTENCE
# 0         HARRY   Lumos Maxima...
# 1         HARRY   Lumos Maxima...
# 2         HARRY   Lumos Maxima...
# 3         HARRY  Lumos... MAXIMA!
# 4  AUNT PETUNIA     Harry! Harry!

# %%
hp2["Character"].unique()
# Out:
# array(['HARRY ', 'VERNON', 'HARRY', 'PETUNIA', 'UNCLE VERNON', 'DUDLEY',
#        'AUNT PETUNIA', 'DOBBY', 'DOBBY ', 'UNCLE VERNON ', 'RON',
#        'GEORGE', 'FRED', 'GEORGE ', 'AUNT\xa0PETUNIA\xa0& DUDLEY  ',
#        'DUDLEY ', 'RON ', 'FRED ', 'MRS. WEASLEY ', 'GINNY ',
#        'MR. WEASLEY', 'FRED, GEORGE, RON  ', 'FRED, GEORGE, RON, HARRY  ',
#        'PERCY ', 'MR. BORGIN', 'LUCIUS MALFOY', 'DRACO', 'LUCIUS MALFOY ',
#        'WITCH', 'HAGRID', 'HERMIONE', 'MAN', 'PHOTOGRAPHER', 'LOCKHART',
#        'MRS. WEASLEY', 'TRAINMASTER', 'HARRY AND RON', 'FILCH', 'SNAPE',
#        'DUMBLEDORE', 'MCGONAGALL', 'PROFESSOR SPROUT', 'CLASS', 'SEAMUS',
#        'PENELOPE CLEARWATER', 'SIR NICHOLAS', 'COLIN', 'DEAN', 'SEAMUS ',
#        'NEVILLE', 'GILDEROY LOCKHART', 'CORNISH PIXIES', 'WOOD', 'FLINT',
#        'VOICE', 'BOY', 'PICTURE', 'LEE JORDAN', 'SLYTHERINS',
#        'MADAM POMFREY', 'MOANING MYRTLE', 'JUSTIN FINCH-FLETCHLEY',
# ...

# %%
hp1["Character"] = hp1["Character"].str.strip()
hp2["Character"] = hp2["Character"].str.strip()
hp3["Character"] = hp3["Character"].str.strip()

# %%
hp3.rename(columns={'CHARACTER':'Character',
                        'SENTENCE':'Sentence'},
               inplace=True)

# %%
hp1f.head()
# Out:
#     Character                                           Sentence
# 0  Dumbledore  I should've known that you would be here, Prof...
# 3  Dumbledore                          I'm afraid so, professor.
# 4  Dumbledore                              The good and the bad.
# 6  Dumbledore                            Hagrid is bringing him.
# 8  Dumbledore  Ah, Professor, I would trust Hagrid with my life.

# %%
hp2f["Character"].unique()
# Out:
# array(['HARRY', 'RON', 'HAGRID', 'HERMIONE', 'DUMBLEDORE', 'NEVILLE'],
#       dtype=object)

# %%
hp1f = hp1.loc[(hp1["Character"]=="Harry")|(hp1["Character"]=="Ron")|(hp1["Character"]=="Hermione")|(hp1["Character"]=="Dumbledore")|(hp1["Character"]=="Neville")|(hp1["Character"]=="Hagrid")]
hp2f = hp2.loc[(hp2["Character"]=="HARRY")|(hp2["Character"]=="RON")|(hp2["Character"]=="HERMIONE")|(hp2["Character"]=="DUMBLEDORE")|(hp2["Character"]=="NEVILLE")|(hp2["Character"]=="HAGRID")]
hp3f = hp3.loc[(hp3["Character"]=="HARRY")|(hp3["Character"]=="RON")|(hp3["Character"]=="HERMIONE")|(hp3["Character"]=="DUMBLEDORE")|(hp3["Character"]=="NEVILLE")|(hp3["Character"]=="HAGRID")]
#['Harry','Ron',"Hermione","Dumbledore","Neville","Hagrid"])
#color_and_shape = df.loc[(df['Color'] == 'Green') & (df['Shape'] == 'Rectangle')]

# %%
hp2f = hp2f.astype(str).apply(lambda x: x.str.lower())
hp3f = hp3f.astype(str).apply(lambda x: x.str.lower())
hp2f['Character'] = hp2f['Character'].str.capitalize()
hp3f['Character'] = hp3f['Character'].str.capitalize()
hp2f['Sentence'] = hp2f['Sentence'].str.capitalize()
hp3f['Sentence'] = hp3f['Sentence'].str.capitalize()

# %%
newhp1=hp1f.assign(Film="Harry Potter and the Philosopher's Stone")
newhp2=hp2f.assign(Film="Harry Potter and the Chamber of Secrets")
newhp3=hp3f.assign(Film="Harry Potter and the Prisoner of Azkaban")

# %%
newhp3.sample()
# Out:
#      Character                Sentence  \
# 1435  Hermione  And we aren't leaving?
#
#                                           Film
# 1435  Harry Potter and the Prisoner of Azkaban

# %%
newhp1.loc[newhp1['Character'] == 'Harry', 'Id'] = 1
newhp1.loc[newhp1['Character'] == 'Ron', 'Id'] = 2
newhp1.loc[newhp1['Character'] == 'Hermione', 'Id'] = 3
newhp1.loc[newhp1['Character'] == 'Dumbledore', 'Id'] = 4
newhp1.loc[newhp1['Character'] == 'Hagrid', 'Id'] = 5
newhp1.loc[newhp1['Character'] == 'Neville', 'Id'] = 6

# %%
newhp1.drop(['c1'], axis=1, inplace=True)

# %%
newhp1.sample(10)
# Out:
#      Character                                           Sentence  \
# 1224     Harry                                  What is it, Fang?
# 1254     Harry  With the Elixir of Life, Voldemort will be str...
# 659   Hermione                                     What an idiot.
# 278      Harry                            I still need... a wand.
# 550        Ron                                  Look at that one.
# 1463     Harry                      Th-then you let the troll in.
# 301      Harry                           And who owned that wand?
# 884      Harry                                          A little.
# 945     Hagrid          Shouldn'ta said that.  No more questions!
# 1339       Ron                                             What?!
#
#                                           Film   Id
# 1224  Harry Potter and the Philosopher's Stone  1.0
# 1254  Harry Potter and the Philosopher's Stone  1.0
# 659   Harry Potter and the Philosopher's Stone  3.0
# ...

# %%
newhp1 = newhp1.dropna(how='all')

# %%
newhp1.isna()
# Out:
#       Character  Sentence   Film     Id
# 0         False     False  False  False
# 3         False     False  False  False
# 4         False     False  False  False
# 6         False     False  False  False
# 8         False     False  False  False
# ...         ...       ...    ...    ...
# 1582      False     False  False  False
# 1583      False     False  False  False
# 1584      False     False  False  False
# 1585      False     False  False  False
# 1586      False     False  False  False
#
# [1016 rows x 4 columns]

# %%
newhp2.loc[newhp2['Character'] == 'Harry', 'Id'] = 1
newhp2.loc[newhp2['Character'] == 'Ron', 'Id'] = 2
newhp2.loc[newhp2['Character'] == 'Hermione', 'Id'] = 3
newhp2.loc[newhp2['Character'] == 'Dumbledore', 'Id'] = 4
newhp2.loc[newhp2['Character'] == 'Hagrid', 'Id'] = 5
newhp2.loc[newhp2['Character'] == 'Neville', 'Id'] = 6

# %%
newhp3.loc[newhp3['Character'] == 'Harry', 'Id'] = 1
newhp3.loc[newhp3['Character'] == 'Ron', 'Id'] = 2
newhp3.loc[newhp3['Character'] == 'Hermione', 'Id'] = 3
newhp3.loc[newhp3['Character'] == 'Dumbledore', 'Id'] = 4
newhp3.loc[newhp3['Character'] == 'Hagrid', 'Id'] = 5
newhp3.loc[newhp3['Character'] == 'Neville', 'Id'] = 6

# %%
newhp2 = newhp2.dropna(how='all')
newhp3 = newhp3.dropna(how='all')

# %%
newhp1.head()
# Out:
#     Character                                           Sentence  \
# 0  Dumbledore  I should've known that you would be here, Prof...
# 3  Dumbledore                          I'm afraid so, professor.
# 4  Dumbledore                              The good and the bad.
# 6  Dumbledore                            Hagrid is bringing him.
# 8  Dumbledore  Ah, Professor, I would trust Hagrid with my life.
#
#                                        Film  Id
# 0  Harry Potter and the Philosopher's Stone   4
# 3  Harry Potter and the Philosopher's Stone   4
# 4  Harry Potter and the Philosopher's Stone   4
# 6  Harry Potter and the Philosopher's Stone   4
# 8  Harry Potter and the Philosopher's Stone   4

# %%
newhp2["Id"] = newhp2["Id"].astype(float).astype(int)
newhp3["Id"] = newhp3["Id"].astype(float).astype(int)

# %%
newhp1["Id"] = newhp1["Id"].astype(float).astype(int)
# Out:
# <ipython-input-217-4602bed36a5a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newhp1["Id"] = newhp1["Id"].astype(float).astype(int)

# %%
newhp1=newhp1.assign(Id_Film=1)
newhp2=newhp2.assign(Id_Film=2)
newhp3=newhp3.assign(Id_Film=3)

# %%
finaldf = pd.concat([newhp1, newhp2,newhp3], ignore_index=True)

# %%
finaldf.sample(5)
#primero las pelis, luego los personajes y finalmente las frases para que rellenen con las foreign keys de las otras tablas
# Out:
#      Character                                           Sentence  \
# 2680  Hermione                                          Bombarda!
# 43       Harry                Because there's no post on Sundays?
# 1653     Harry  One, but it's not powerful enough for all of t...
# 926      Harry         Take care of Ron. Then, go to the owlery.
# 281     Hagrid                Right, then. This way to the boats.
#
#                                           Film  Id  Id_Film
# 2680  Harry Potter and the Prisoner of Azkaban   3        3
# 43    Harry Potter and the Philosopher's Stone   1        1
# 1653   Harry Potter and the Chamber of Secrets   1        2
# 926   Harry Potter and the Philosopher's Stone   1        1
# 281   Harry Potter and the Philosopher's Stone   5        1

# %%
finaldf["Film"] = finaldf["Film"].str.replace("'",'')

# %%
finaldf["Sentence"] = finaldf["Sentence"].str.replace("'",'')

# %%
finaldf
# Out:
#        Character                                           Sentence  \
# 0     Dumbledore  I shouldve known that you would be here, Profe...
# 1     Dumbledore                           Im afraid so, professor.
# 2     Dumbledore                              The good and the bad.
# 3     Dumbledore                            Hagrid is bringing him.
# 4     Dumbledore  Ah, Professor, I would trust Hagrid with my life.
# ...          ...                                                ...
# 2713    Hermione                             How fast is it, harry?
# 2714       Harry                                             Lumos.
# 2715       Harry          I solemnly swear that i am up to no good.
# 2716       Harry                                  Mischief managed.
# 2717       Harry                                               Nox.
#
#                                           Film  Id  Id_Film
# 0      Harry Potter and the Philosophers Stone   4        1
# ...

# %%
finaldf.drop(["Character","Film"],axis=1,inplace=True)

# %%
finaldf["Index"] = finaldf.index

# %%
finaldf.rename(columns={'Index':'Id_Sentence',
                        'Id':'Id_Characters'},
               inplace=True)

# %%
finaldf
# Out:
#                                                Sentence  Id_Characters  \
# 0     I should've known that you would be here, Prof...              4
# 1                             I'm afraid so, professor.              4
# 2                                 The good and the bad.              4
# 3                               Hagrid is bringing him.              4
# 4     Ah, Professor, I would trust Hagrid with my life.              4
# ...                                                 ...            ...
# 2713                             How fast is it, harry?              3
# 2714                                             Lumos.              1
# 2715          I solemnly swear that i am up to no good.              1
# 2716                                  Mischief managed.              1
# 2717                                               Nox.              1
#
#       Id_Film  Id_Sentence
# 0           1            0
# 1           1            1
# 2           1            2
# ...

# %% [markdown]
# Film df

# %%
finaldf.loc[finaldf['Id_Characters'] == 1] = 47
finaldf.loc[finaldf['Id_Characters'] == 2] = 48
finaldf.loc[finaldf['Id_Characters'] == 3] = 49
finaldf.loc[finaldf['Id_Characters'] == 4] = 50
finaldf.loc[finaldf['Id_Characters'] == 5] = 51
finaldf.loc[finaldf['Id_Characters'] == 6] = 52

# %%
finaldf
# Out:
#      Sentence  Id_Characters  Id_Film  Id_Sentence
# 0          50             50       50           50
# 1          50             50       50           50
# 2          50             50       50           50
# 3          50             50       50           50
# 4          50             50       50           50
# ...       ...            ...      ...          ...
# 2713       49             49       49           49
# 2714       47             47       47           47
# 2715       47             47       47           47
# 2716       47             47       47           47
# 2717       47             47       47           47
#
# [2718 rows x 4 columns]

# %%
lst1 = [1,2,3]
lst2 = ["Harry Potter and the Philosophers Stone","Harry Potter and the Chamber of Secrets","Harry Potter and the Prisoner of Azkaban"]
filmdf = pd.DataFrame(list(zip(lst1,lst2)), columns = ['Id_Film','Film'])
print(filmdf)
# Out:
#    Id_Film                                      Film
# 0        1   Harry Potter and the Philosophers Stone
# 1        2   Harry Potter and the Chamber of Secrets
# 2        3  Harry Potter and the Prisoner of Azkaban

# %%
filmdf
# Out:
#    Id_Film                                      Film
# 0        1   Harry Potter and the Philosophers Stone
# 1        2   Harry Potter and the Chamber of Secrets
# 2        3  Harry Potter and the Prisoner of Azkaban

# %%
Character.replace({"Harry James Potter":"Harry","Ronald Bilius Weasley":"Ron","Neville Longbottom":"Neville","Hermione Jean Granger":"Hermione","Albus Percival Wulfric Brian Dumbledore":"Dumbledore","Rubeus Hagrid":"Hagrid"},inplace=True)

# %%
Characterf = Character.loc[(Character["Name"]=="Harry")|(Character["Name"]=="Ron")|(Character["Name"]=="Hermione")|(Character["Name"]=="Dumbledore")|(Character["Name"]=="Neville")|(Character["Name"]=="Hagrid")]
Characterf
# Out:
#    Id        Name  Gender                                                Job  \
# 0   1       Harry    Male                                            Student
# 1   2         Ron    Male                                            Student
# 2   3    Hermione  Female                                            Student
# 3   4  Dumbledore    Male                                         Headmaster
# 4   5      Hagrid    Male  Keeper of Keys and Grounds | Professor of Care...
# 5   6     Neville    Male                                            Student
#
#         House                                Wand              Patronus  \
# 0  Gryffindor         11"  Holly  phoenix feather                  Stag
# 1  Gryffindor          12" Ash unicorn tail hair   Jack Russell terrier
# 2  Gryffindor  10¾"  vine wood dragon heartstring                 Otter
# 3  Gryffindor   15" Elder Thestral tail hair core               Phoenix
# ...

# %%
Characterf["Blood_status"] = Characterf["Blood_status"].str.replace('-','')
# Out:
# <ipython-input-308-6f155522f028>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Characterf["Blood_status"] = Characterf["Blood_status"].str.replace('-','')

# %%
Characterf
# Out:
#    Id        Name  Gender                                                Job  \
# 0   1       Harry    Male                                            Student
# 1   2         Ron    Male                                            Student
# 2   3    Hermione  Female                                            Student
# 3   4  Dumbledore    Male                                         Headmaster
# 4   5      Hagrid    Male  Keeper of Keys and Grounds | Professor of Care...
# 5   6     Neville    Male                                            Student
#
#         House                                Wand              Patronus  \
# 0  Gryffindor         11"  Holly  phoenix feather                  Stag
# 1  Gryffindor          12" Ash unicorn tail hair   Jack Russell terrier
# 2  Gryffindor  10¾"  vine wood dragon heartstring                 Otter
# 3  Gryffindor   15" Elder Thestral tail hair core               Phoenix
# ...

# %%
Characterf.columns = [i.replace(" ","_").strip() for i in Characterf.columns]

# %%
Characterf
# Out:
#    Id        Name  Gender                                                Job  \
# 0   1       Harry    Male                                            Student
# 1   2         Ron    Male                                            Student
# 2   3    Hermione  Female                                            Student
# 3   4  Dumbledore    Male                                         Headmaster
# 4   5      Hagrid    Male  Keeper of Keys and Grounds | Professor of Care...
# 5   6     Neville    Male                                            Student
#
#         House                                Wand              Patronus  \
# 0  Gryffindor         11"  Holly  phoenix feather                  Stag
# 1  Gryffindor          12" Ash unicorn tail hair   Jack Russell terrier
# 2  Gryffindor  10¾"  vine wood dragon heartstring                 Otter
# 3  Gryffindor   15" Elder Thestral tail hair core               Phoenix
# ...

# %%
Characterf["Skills"]
# Out:
# 0    Parseltongue| Defence Against the Dark Arts | ...
# 1                 Wizard chess | Quidditch goalkeeping
# 2                                    Almost everything
# 3    Considered by many to be one of the most power...
# 4    Resistant to stunning spells| above average st...
# 5                                            Herbology
# Name: Skills, dtype: object

# %%
import pymysql
import os
from dotenv import load_dotenv
load_dotenv()
from sqlalchemy import create_engine
from getpass import getpass
import sqlalchemy as alch
password = os.getenv("password")

db_name = "harrypotter"
conec = f"mysql+pymysql://root:{password}@localhost/harrypotter"
engine = alch.create_engine(conec)

# %%
for i in lst2:
    engine.execute(f'INSERT INTO `harrypotter`.`films` (`Film`) VALUES ("{i}");')

# %%
for i,row in Characterf.iterrows():
    engine.execute(f"""
    INSERT INTO `harrypotter`.`characters` (Name) VALUES ('{row["Name"]}');
    """)

# %%
for i,row in Characterf.iterrows():
    engine.execute(f"""
    INSERT INTO `harrypotter`.`characters` (Name,Gender,Job,House,Patronus,Species) VALUES ('{row["Name"]}','{row["Gender"]}','{row["Job"]}','{row["House"]}','{row["Patronus"]}','{row["Species"]}');
    """)

# %%
for i,row in finaldf.iterrows():
    engine.execute(f"""
    INSERT INTO `harrypotter`.`phrases` (Sentence, Films_ ) VALUES ('{row["Name"]}','{row["Gender"]}','{row["Job"]}','{row["House"]}','{row["Patronus"]}','{row["Species"]}');
    """)

# %%
def dameId(que,string):
    """
    Devuelve el ID de lo que le pidamos sabiendo que ese elemento EXISTE
    """
    if que == "pelicula":
        return list(engine.execute(f"SELECT Film_ID FROM Films WHERE Film ='{string}';"))[0][0]
    elif que == "personaje":
        return list(engine.execute(f"SELECT ID FROM Characters WHERE Name ='{string}';"))[0][0]

# %%
dameId("pelicula","Harry Potter and the Philosophers Stone")
# Out:
# 7

# %%
def insertarfrases(x):
    Id_personaje = dameId("personaje",row['Character'])
    Id_pelicula = dameId("pelicula",row['Film'])
    engine.execute(f"""
    INSERT INTO `harrypotter`.`phrases` (Sentence, Films_Film_ID,Characters_ID) VALUES ('{row["Sentence"]}','{Id_pelicula}','{Id_personaje}');
    """)

# %%
for i,row in finaldf.iterrows():
    insertarfrases(row)

# %% [markdown]
# ### Datos en SQL listos

# %%
# !pip install flask

# %%
from flask import Flask, request
from flask import jsonify

# %%
app = Flask(__name__)

@app.route("/")
def inicio():
    return "characters"

# %%
app = Flask(__name__)

#@app.route("/")
def inicial():
    return jsonify("hola mundo")

@app.route("/dado")
def dado():
    parsear = jsonify(da.tiraeldado())
    return parsear
    


@app.route("/refran")
def dameunrefran():
    refran = dat.refranes()
    return jsonify(refran)


@app.route("/unamuyfacil")
def facil():
    return jsonify(dat.pepe())






@app.route("/refrantuneado")
def refran_t():
    # parámetros entre paréntesis no obligatorios
    lan = request.args.get("idioma")
    # Parámetro entre corchetes, obligatorio (required) si no está, la api devuelve error 500
    frase = request.args["algo"]
    refran = dat.refranes_2(lan)
    diccionario = {"tú me has dicho": frase, "yo te digo": refran}
    return jsonify(diccionario)



if __name__ == '__main__':
    app.run(debug=False)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [29/Nov/2021 18:27:16] "GET / HTTP/1.1" 200 -

# %%
@app.route("/")
def inicial():
    return jsonify("hola mundo")

@app.route("/dado")
def dado():
    parsear = jsonify(da.tiraeldado())
    return parsear
    


@app.route("/refran")
def dameunrefran():
    refran = dat.refranes()
    return jsonify(refran)


@app.route("/unamuyfacil")
def facil():
    return jsonify(dat.pepe())






@app.route("/refrantuneado")
def refran_t():
    # parámetros entre paréntesis no obligatorios
    lan = request.args.get("idioma")
    # Parámetro entre corchetes, obligatorio (required) si no está, la api devuelve error 500
    frase = request.args["algo"]
    refran = dat.refranes_2(lan)
    diccionario = {"tú me has dicho": frase, "yo te digo": refran}
    return jsonify(diccionario)
